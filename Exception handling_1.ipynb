# %%
Q1 What is an Exception in python? write the difference between Exception and syntax error


ANSWER) Exception is the module in python to handle the run time errors and helps the program to run further Whereas syntax error are identified while coding
The synatx error occurs when the coding is not executed as per python standards. The syntax erroro cannot handle run time error but the exception handler does


Q2 What happens when the exception is not handled?Explain with example

ANSWER) When the exception is not handled then the program will be terminated immedietly

Example: when the user enters the age in alphabets instead of integer then the program terminates
age = int(input("enter the age"))
print(age)

Q3 Which python statements are used to catch exceptions? explain with example

The except is used to catch the exception. In the below example when the user is asked for a age and he enters age in 
alphabets instead of using integers, so the  ValueError exception handles the exception

try:
    age = int(input("enter the age"))
    print(age)
except ValueError as E:
    print(E)
    
Q4 Explain with example :

a try and else
b finally
c raise

try and else

The funtnality or code for the desied outcome is written in try block

The else block is executed everytime the try block is successful without any errors

finally
Finally will execute everytime irrespective of the eception handling results



try:
    age = int(input("enter the age"))
    print(age)
except ValueError as E:
    print(E)
else:
    print("Else will execute if try block is sucessful")
finally:
    print("Finally will execute everytime irrespective of the eception handling results")



raise can be usued to trigger the exceptioins that is defined (example below)

    
(custom exception)
class valage(Exception):
    def __init__(self,message):
        self.message=message
        

try:
    
    age=int(input("enter the age)
    if age>100:
        raise valage("Entered age is unatural, please enter the correct age")
except Exception as e:
    print(e)

                  
Q5 What are custom exceptions in python? why do we need custom exceptions? explain with example
                  
The custom exceptions lets the user to create the exceptions based on the application requirement
In compiling, the coding standards are only checked, but there may be scenario where the user input standard may be correct but not the value level
                  
In below example user is asked to enter the age. when the user enter age more than 120. it is incorrect in the logical way. but correct on the type
to hadle these errors we use custom exceptions
                  
                  
(custom exception)
class valage(Exception):
    def __init__(self,message):
        self.message=message
        

try:
    
    age=int(input("enter the age
    if age>100:
        raise valage("Entered age is unatural, please enter the correct age")
except Exception as e:
    print(e)

                  
Q6 create a custom exception class use this class to handle an exception
                  
                  
(custom exception)
class valage(Exception):
    def __init__(self,message):
        self.message=message
        

try:
    
    age=int(input("enter the age
    if age>100:
        raise valage("Entered age is unatural, please enter the correct age")
except Exception as e:
    print(e)

# %%
try:
    age = int(input("enter the age"))
    print(age)
except ValueError as E:
    print(E)
# Out:
# enter the age dcc
# invalid literal for int() with base 10: 'dcc'
